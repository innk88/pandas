# %% [markdown]
# <a href="https://colab.research.google.com/github/innk88/pandas/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime
df = pd.read_csv ('covid_data_cleaned.csv')

# %%
df.info()
df.describe()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183583 entries, 0 to 183582
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   iso_code                 183583 non-null  object
#  1   continent                172860 non-null  object
#  2   location                 183583 non-null  object
#  3   date                     183583 non-null  object
#  4   total_cases              176745 non-null  float64
#  5   new_cases                176532 non-null  float64
#  6   total_deaths             158467 non-null  float64
#  7   new_deaths               158464 non-null  float64
#  8   total_vaccinations       50011 non-null   float64
#  9   people_vaccinated        47564 non-null   float64
#  10  people_fully_vaccinated  45066 non-null   float64
#  11  total_boosters           22431 non-null   float64
#  12  new_vaccinations         41060 non-null   float64
# dtypes: float64(9), object(4)
# ...

# %%
df['date'] = pd.to_datetime (df['date'], format = '%d/%m/%y')
df.dtypes
df
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 183578      ZWE    Africa     Zimbabwe 2022-04-29     247842.0       58.0
# 183579      ZWE    Africa     Zimbabwe 2022-04-30     247875.0       33.0
# 183580      ZWE    Africa     Zimbabwe 2022-05-01     247911.0       36.0
# 183581      ZWE    Africa     Zimbabwe 2022-05-02     247935.0       24.0
# 183582      ZWE    Africa     Zimbabwe 2022-05-03     247990.0       55.0
#
#         total_deaths  new_deaths  total_vaccinations  people_vaccinated  \
# ...

# %%
df_kenya = df[df.location=='Kenya']
df_kenya
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 86955      KEN    Africa    Kenya 2020-03-06          NaN        NaN
# 86956      KEN    Africa    Kenya 2020-03-07          NaN        NaN
# 86957      KEN    Africa    Kenya 2020-03-08          NaN        NaN
# 86958      KEN    Africa    Kenya 2020-03-09          NaN        NaN
# 86959      KEN    Africa    Kenya 2020-03-10          NaN        NaN
# ...        ...       ...      ...        ...          ...        ...
# 87739      KEN    Africa    Kenya 2022-04-29     323760.0       15.0
# 87740      KEN    Africa    Kenya 2022-04-30     323773.0       13.0
# 87741      KEN    Africa    Kenya 2022-05-01     323786.0       13.0
# 87742      KEN    Africa    Kenya 2022-05-02     323792.0        6.0
# 87743      KEN    Africa    Kenya 2022-05-03     323796.0        4.0
#
#        total_deaths  new_deaths  total_vaccinations  people_vaccinated  \
# ...

# %%
# @title date vs new_cases

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['date']
  ys = series['new_cases']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df_russia.sort_values('date', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('date')
_ = plt.ylabel('new_cases')

# %%
df_russia['total_deathsX'] = df_russia.total_deaths * 500    #добавляем столбец total_deathsX, значения которого умножаются на 100 от оригинального столбца для лучшего масштабирования на графике
df_russia['new_casesX'] = df_russia['new_cases'] * 1000 # аналогично создаем новый столбец с масштабированными значениями
df_russia.plot ( x = 'date', y = [ 'people_vaccinatedX', 'total_deathsX', 'new_casesX'], figsize = (20, 8))
# Out:
# <ipython-input-35-746b77737522>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-35-746b77737522>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-746b77737522> in <cell line: 3>()
# ...

# %%
import math
pd.options.plotting.backend = "plotly"
df_russia['total_deathsX'] = df_russia.total_deaths * 500
x=0
df_russia['people_vaccinatedX'] = df_russia.people_vaccinated
for n in df_russia.people_vaccinatedX:
   if (math.isnan(n)):
    n=x
    print(n)
   else:
    x=n

df_russia['new_casesX'] = df_russia['new_cases'] * 500
df_russia.plot (kind='line',x = 'date', y = [ 'people_vaccinatedX', 'total_deathsX', 'new_casesX'])
# Out:
# <ipython-input-36-2807158c49d1>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-36-2807158c49d1>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-36-2807158c49d1>:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
   #добавляем столбец total_deathsX, значения которого умножаются на 100 от оригинального столбца для лучшего масштабирования на графике
df_russia['new_casesX'] = df_russia['new_cases'] * 1000 # аналогично создаем новый столбец с масштабированными значениями
df_russia.plot (x = 'date', y = [ 'people_vaccinated', 'new_casesX'], figsize = (20, 8))
# Out:
# <ipython-input-16-5bbfcf309606>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_russia['new_casesX'] = df_russia['new_cases'] * 1000 # аналогично создаем новый столбец с масштабированными значениями
# <Axes: xlabel='date'>

# %%
df_china = df[df.location=='China']
df_china
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 34065      CHN      Asia    China 2020-01-22        547.0        NaN
# 34066      CHN      Asia    China 2020-01-23        639.0       92.0
# 34067      CHN      Asia    China 2020-01-24        916.0      277.0
# 34068      CHN      Asia    China 2020-01-25       1399.0      483.0
# 34069      CHN      Asia    China 2020-01-26       2062.0      663.0
# ...        ...       ...      ...        ...          ...        ...
# 34893      CHN      Asia    China 2022-04-29     951031.0    28853.0
# 34894      CHN      Asia    China 2022-04-30     952412.0     1381.0
# 34895      CHN      Asia    China 2022-05-01    1002919.0    50507.0
# 34896      CHN      Asia    China 2022-05-02    1022910.0    19991.0
# 34897      CHN      Asia    China 2022-05-03    1039372.0    16462.0
#
#        total_deaths  new_deaths  total_vaccinations  people_vaccinated  \
# ...

# %%
df_malaysia = df[df.location=='Malaysia']
df_malaysia
# Out:
#        iso_code continent  location       date  total_cases  new_cases  \
# 101509      MYS      Asia  Malaysia 2020-01-24          NaN        NaN
# 101510      MYS      Asia  Malaysia 2020-01-25          4.0        4.0
# 101511      MYS      Asia  Malaysia 2020-01-26          4.0        0.0
# 101512      MYS      Asia  Malaysia 2020-01-27          4.0        0.0
# 101513      MYS      Asia  Malaysia 2020-01-28          4.0        0.0
# ...         ...       ...       ...        ...          ...        ...
# 102335      MYS      Asia  Malaysia 2022-04-29    4445897.0     2579.0
# 102336      MYS      Asia  Malaysia 2022-04-30    4448004.0     2107.0
# 102337      MYS      Asia  Malaysia 2022-05-01    4449507.0     1503.0
# 102338      MYS      Asia  Malaysia 2022-05-02    4450859.0     1352.0
# 102339      MYS      Asia  Malaysia 2022-05-03    4451781.0      922.0
#
#         total_deaths  new_deaths  total_vaccinations  people_vaccinated  \
# ...

# %%
df_india= df[df.location=='India']
df_india
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 76119      IND      Asia    India 2020-01-30          1.0        1.0
# 76120      IND      Asia    India 2020-01-31          1.0        0.0
# 76121      IND      Asia    India 2020-02-01          1.0        0.0
# 76122      IND      Asia    India 2020-02-02          2.0        1.0
# 76123      IND      Asia    India 2020-02-03          3.0        1.0
# ...        ...       ...      ...        ...          ...        ...
# 76939      IND      Asia    India 2022-04-29   43075864.0     3688.0
# 76940      IND      Asia    India 2022-04-30   43079188.0     3324.0
# 76941      IND      Asia    India 2022-05-01   43082345.0     3157.0
# 76942      IND      Asia    India 2022-05-02   43084913.0     2568.0
# 76943      IND      Asia    India 2022-05-03   43088118.0     3205.0
#
#        total_deaths  new_deaths  total_vaccinations  people_vaccinated  \
# ...

# %%
df_japan = df[df.location=='Japan']
# аналогичная запись для фильтра, но немного с другим синтаксисом:
# df_russia = df[df['location'] == "Russia"]
df_japan
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 84141      JPN      Asia    Japan 2020-01-22          2.0        NaN
# 84142      JPN      Asia    Japan 2020-01-23          2.0        0.0
# 84143      JPN      Asia    Japan 2020-01-24          2.0        0.0
# 84144      JPN      Asia    Japan 2020-01-25          2.0        0.0
# 84145      JPN      Asia    Japan 2020-01-26          4.0        2.0
# ...        ...       ...      ...        ...          ...        ...
# 84969      JPN      Asia    Japan 2022-04-29    7846274.0    36606.0
# 84970      JPN      Asia    Japan 2022-04-30    7871253.0    24979.0
# 84971      JPN      Asia    Japan 2022-05-01    7898133.0    26880.0
# 84972      JPN      Asia    Japan 2022-05-02    7917391.0    19258.0
# 84973      JPN      Asia    Japan 2022-05-03    7947818.0    30427.0
#
#        total_deaths  new_deaths  total_vaccinations  people_vaccinated  \
# ...

# %%
import matplotlib.pyplot as plt

df1 = df.loc[df['location'] == 'Indonesia',['date', 'total_cases']]
df2 = df.loc[df['location'] == 'China',['date', 'total_cases']]
df3 = df.loc[df['location'] == 'Japan', ['date', 'total_cases']]
df4 = df.loc[df['location'] == 'Malaysia', ['date', 'total_cases']]

plt.figure (figsize = (20, 8)) # зададим размер полотна графика в дюймах
plt.plot (df1['date'], df1['total_cases'], label = 'Indonesia total cases')
plt.plot (df2['date'], df2['total_cases'], label = 'China total cases')
plt.plot (df3['date'], df3['total_cases'], label = 'Japan total cases')
plt.plot (df4['date'], df4['total_cases'], label = 'Malaysia total cases')
plt.legend(fontsize=20)

plt.show ()
